# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Global Landslide Data.xlsx",index_col='id')

# %%
df.columns
# Out:
# Index(['date', 'time', 'country', 'nearest_places', 'hazard_type',
#        'landslide_type', 'trigger', 'storm_name', 'fatalities', 'injuries',
#        'source_name', 'source_link', 'comments', 'location_description',
#        'location_accuracy', 'landslide_size', 'photos_link', 'cat_src',
#        'cat_id', 'countryname', 'near', 'distance', 'adminname1', 'adminname2',
#        'population', 'countrycode', 'continentcode', 'key', 'version',
#        'tstamp', 'changeset_id', 'latitude', 'longitude', 'geolocation'],
#       dtype='object')

# %%
df.shape
# Out:
# (1693, 34)

# %%
df.head()
# Out:
#            date      time     country  \
# id
# 7494 2015-09-25       NaN         NaN
# 249  2007-09-09       NaN  Costa Rica
# 250  2007-09-09       NaN    Dominica
# 7541 2016-03-02  08:00:00         NaN
# 7533 2016-02-27  12:15:00         NaN
#
#                                          nearest_places hazard_type  \
# id
# 7494                           Barrio Tournon, San Jose   landslide
# 249                                             Heredia   landslide
# 250                        entire island, Roseau closed   landslide
# 7541  south bound travel lane of Interstate 91 in Wi...   landslide
# 7533                           Simmons Avenue, Bramwell   landslide
#
#      landslide_type  trigger     storm_name  fatalities  injuries  ...  \
# id                                                                 ...
# 7494      Landslide     Rain            NaN         0.0       0.0  ...
# 249       Landslide     Rain            NaN         NaN       NaN  ...
# ...

# %%
# sns.pairplot(df,hue="landslide_type")
# plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1693 entries, 7494 to 7042
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  1690 non-null   datetime64[ns]
#  1   time                  629 non-null    object
#  2   country               1286 non-null   object
#  3   nearest_places        1683 non-null   object
#  4   hazard_type           1693 non-null   object
#  5   landslide_type        1692 non-null   object
#  6   trigger               1691 non-null   object
#  7   storm_name            134 non-null    object
#  8   fatalities            1446 non-null   float64
#  9   injuries              515 non-null    float64
#  10  source_name           872 non-null    object
#  11  source_link           1593 non-null   object
#  12  comments              1652 non-null   object
#  13  location_description  552 non-null    object
# ...

# %%
objList = df.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['time', 'country', 'nearest_places', 'hazard_type', 'landslide_type',
#        'trigger', 'storm_name', 'source_name', 'source_link', 'comments',
#        'location_description', 'location_accuracy', 'landslide_size',
#        'photos_link', 'cat_src', 'cat_id', 'countryname', 'near', 'adminname1',
#        'adminname2', 'countrycode', 'continentcode', 'key', 'tstamp',
#        'changeset_id', 'geolocation'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date                       3
# time                    1064
# country                  407
# nearest_places            10
# hazard_type                0
# landslide_type             1
# trigger                    2
# storm_name              1559
# fatalities               247
# injuries                1178
# source_name              821
# source_link              100
# comments                  41
# location_description    1141
# location_accuracy          0
# landslide_size             1
# photos_link             1490
# cat_src                    1
# cat_id                     0
# countryname                0
# near                       1
# distance                   1
# adminname1                 1
# adminname2               434
# population                 1
# countrycode                0
# continentcode           1528
# key                        0
# version                    0
# tstamp                     1
# changeset_id               0
# latitude                   0
# ...

# %%
df=df.drop(['time','storm_name','injuries','source_name','key','source_link','location_description','photos_link','adminname1','adminname2','continentcode','country','hazard_type','comments','fatalities','nearest_places','changeset_id','cat_src','cat_id'],1)

# %%
df=df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# date                 0
# landslide_type       0
# trigger              0
# location_accuracy    0
# landslide_size       0
# countryname          0
# near                 0
# distance             0
# population           0
# countrycode          0
# version              0
# tstamp               0
# latitude             0
# longitude            0
# geolocation          0
# dtype: int64

# %%
df.shape
# Out:
# (1686, 15)

# %%
df.head()
# Out:
#            date landslide_type  trigger   location_accuracy landslide_size  \
# id
# 7494 2015-09-25      Landslide     Rain    Known_within_1km          Small
# 249  2007-09-09      Landslide     Rain   Known_within_5_km         Medium
# 250  2007-09-09      Landslide     Rain  Known_within_25_km         Medium
# 7541 2016-03-02      Rock_Fall  Unknown   Known_within_10km          Small
# 7533 2016-02-27      Rock_Fall  Unknown    Known_within_1km          Small
#
#         countryname       near  distance  population countrycode  version  \
# id
# 7494     Costa Rica  San Jos̩   1.16705    335007.0          CR        2
# 249      Costa Rica    Heredia   0.26208     21947.0          CR        1
# 250        Dominica     Roseau   2.59849     16571.0          DM        1
# 7541  United States    Windsor   1.78429      2066.0          US        2
# 7533  United States   Bluewell   5.07093      2184.0          US        1
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'landslide_type', 'trigger', 'location_accuracy',
#        'landslide_size', 'countryname', 'near', 'distance', 'population',
#        'countrycode', 'version', 'tstamp', 'latitude', 'longitude',
#        'geolocation'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1686 entries, 7494 to 34
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1686 non-null   datetime64[ns]
#  1   landslide_type     1686 non-null   object
#  2   trigger            1686 non-null   object
#  3   location_accuracy  1686 non-null   object
#  4   landslide_size     1686 non-null   object
#  5   countryname        1686 non-null   object
#  6   near               1686 non-null   object
#  7   distance           1686 non-null   float64
#  8   population         1686 non-null   float64
#  9   countrycode        1686 non-null   object
#  10  version            1686 non-null   int64
#  11  tstamp             1686 non-null   object
#  12  latitude           1686 non-null   float64
#  13  longitude          1686 non-null   float64
#  14  geolocation        1686 non-null   object
# ...

# %%
df['landslide_type'].unique()
# Out:
# array(['Landslide', 'Rock_Fall', 'Mudslide', 'Debris_Flow',
#        'Riverbank_Collapse', 'Other', 'Complex', 'Creep', 'Rockslide',
#        'mudslide', 'landslide', 'Unknown', 'Snow_Avalanche', 'Rockfall',
#        'Lahar'], dtype=object)

# %%
df['landslide_type'].replace(to_replace=['Landslide','Rock_Fall','Mudslide','Debris_Flow','Riverbank_Collapse','Other','Complex','Creep','Rockslide','mudslide','landslide','Unknown','Snow_Avalanche','Rockfall','Lahar'], value=[1,2,3,4,5,6,7,8,9,3,1,12,13,2,15], inplace=True)

# %%
df['trigger'].unique()
# Out:
# array(['Rain', 'Unknown', 'Continuous_rain', 'Downpour', 'Freeze_thaw',
#        'Tropical_Cyclone', 'Flooding', 'Mining_digging', 'downpour',
#        'Construction', 'Volcano', 'Snowfall_snowmelt',
#        'No_Apparent_trigger', 'Earthquake', 'unknown', 'Continuous_Rain',
#        'Other', 'Dam_Embankment_Collapse'], dtype=object)

# %%
df['trigger'].replace(to_replace=['Rain', 'Unknown', 'Continuous_rain', 'Downpour', 'Freeze_thaw',
       'Tropical_Cyclone', 'Flooding', 'Mining_digging', 'downpour',
       'Construction', 'Volcano', 'Snowfall_snowmelt',
       'No_Apparent_trigger', 'Earthquake', 'unknown', 'Continuous_Rain',
       'Other', 'Dam_Embankment_Collapse'],value=[1,2,3,4,5,6,7,8,4,10,11,12,13,14,2,3,3,18],inplace=True)

# %%
df['location_accuracy'].unique()
# Out:
# array(['Known_within_1km', 'Known_within_5_km', 'Known_within_25_km',
#        'Known_within_10km', 'Exact_location', 'Known_within_5km',
#        'Known_within_1_km', 'Known_within_15km', 'Known_within_25km',
#        'Known_within_10_km', 'Unknown', 'Known_within_50km',
#        'Exact_Location', 'Known_within_50_km', 'Known_within_2km',
#        'Known_within_15_km', 'Known_within_20_km'], dtype=object)

# %%
df['location_accuracy'].replace(to_replace=['Exact_location','Exact_Location','Known_within_1km','Known_within_1_km','Known_within_2km','Known_within_5km','Known_within_5_km','Known_within_10km','Known_within_10_km','Known_within_15km','Known_within_15_km','Known_within_20_km','Known_within_25_km','Known_within_25km','Known_within_50km', 'Known_within_50_km','Unknown'],value=[0,0,1,1,2,5,5,10,10,15,15,20,25,25,50,50,50],inplace=True)

# %%
df.head()
# Out:
#            date  landslide_type  trigger  location_accuracy landslide_size  \
# id
# 7494 2015-09-25               1        1                  1          Small
# 249  2007-09-09               1        1                  5         Medium
# 250  2007-09-09               1        1                 25         Medium
# 7541 2016-03-02               2        2                 10          Small
# 7533 2016-02-27               2        2                  1          Small
#
#         countryname       near  distance  population countrycode  version  \
# id
# 7494     Costa Rica  San Jos̩   1.16705    335007.0          CR        2
# 249      Costa Rica    Heredia   0.26208     21947.0          CR        1
# 250        Dominica     Roseau   2.59849     16571.0          DM        1
# 7541  United States    Windsor   1.78429      2066.0          US        2
# 7533  United States   Bluewell   5.07093      2184.0          US        1
#
# ...

# %%
df['landslide_size'].unique()
# Out:
# array(['Small', 'Medium', 'Large', 'small', 'Very_large', 'medium',
#        'large'], dtype=object)

# %%
df['landslide_size'].replace(to_replace=['Small', 'Medium', 'Large', 'small', 'Very_large', 'medium','large'],value=[0,1,2,0,3,1,2],inplace=True)

# %%
df.head()
# Out:
#            date  landslide_type  trigger  location_accuracy  landslide_size  \
# id
# 7494 2015-09-25               1        1                  1               0
# 249  2007-09-09               1        1                  5               1
# 250  2007-09-09               1        1                 25               1
# 7541 2016-03-02               2        2                 10               0
# 7533 2016-02-27               2        2                  1               0
#
#         countryname       near  distance  population countrycode  version  \
# id
# 7494     Costa Rica  San Jos̩   1.16705    335007.0          CR        2
# 249      Costa Rica    Heredia   0.26208     21947.0          CR        1
# 250        Dominica     Roseau   2.59849     16571.0          DM        1
# 7541  United States    Windsor   1.78429      2066.0          US        2
# 7533  United States   Bluewell   5.07093      2184.0          US        1
#
# ...

# %%
df=df.drop(['countryname','near','countrycode','tstamp','geolocation'],1)

# %%
df.head()
# Out:
#            date  landslide_type  trigger  location_accuracy  landslide_size  \
# id
# 7494 2015-09-25               1        1                  1               0
# 249  2007-09-09               1        1                  5               1
# 250  2007-09-09               1        1                 25               1
# 7541 2016-03-02               2        2                 10               0
# 7533 2016-02-27               2        2                  1               0
#
#       distance  population  version  latitude  longitude
# id
# 7494   1.16705    335007.0        2    9.9402   -84.0771
# 249    0.26208     21947.0        1   10.0000   -84.1167
# 250    2.59849     16571.0        1   15.3055   -61.3642
# 7541   1.78429      2066.0        2   43.4771   -72.4066
# 7533   5.07093      2184.0        1   37.3287   -81.3134

# %%
x=df
y=df['landslide_type']

# %%
x.shape
# Out:
# (1686, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                    random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(X_test.shape)
# Out:
# (1348, 10)
# (1348,)
# (338, 10)
# (338, 10)
